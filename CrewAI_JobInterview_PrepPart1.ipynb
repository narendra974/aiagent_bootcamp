# %%
from google.colab import userdata
openai_api_key = userdata.get('ai_agents_openai')
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# /tmp/ipykernel_1296/1342621954.py in <cell line: 0>()
#       1 from google.colab import userdata
# ----> 2 openai_api_key = userdata.get('ai_agents_openai')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      64     )
#      65   if not resp:
# ---> 66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
#      68     raise SecretNotFoundError(key)
#
# TimeoutException: Requesting secret ai_agents_openai timed out. Secrets can only be fetched when running from the Colab UI.
