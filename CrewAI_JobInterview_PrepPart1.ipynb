# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
file_path = '/content/drive/My Drive/secret_keys.txt'

with open(file_path, 'r') as f:
    content = f.read()
    # Extract the key from the string 'API_SECRET_KEY = "secret key"'
    secret_key = content.split('"')[1]
    print(f"Secret Key loaded successfully.")
# Out:
# API Key: None
